# %%
# Import the dependencies.
import pandas as pd
import requests
import numpy as np
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]  
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | usinsk
# Processing Record 4 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 1 | naze
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | tautira
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | chitrakonda
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | aklavik
# Processing Record 12 of Set 1 | shu
# Processing Record 13 of Set 1 | dumas
# Processing Record 14 of Set 1 | eureka
# Processing Record 15 of Set 1 | barrow
# Processing Record 16 of Set 1 | tateyama
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | taunggyi
# Processing Record 19 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | norman wells
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | beringovskiy
# Processing Record 28 of Set 1 | lebu
# Processing Record 29 of Set 1 | martapura
# Processing Record 30 of Set 1 | jonesboro
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | provideniya
# Processing Record 33 of Set 1 | ust-kuyga
# Processing Record 34 of Set 1 | margate
# Processing Record 35 of Set 1 | salvador
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | kasli
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | elizabeth city
# Processing Record 40 of Set 1 | dingle
# Processing Record 41 of Set 1 | tiksi
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | acapulco
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | verkhoyansk
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | lure
# Processing Record 50 of Set 1 | clyde river
# Processing Record 1 of Set 2 | tawzar
# City not found. Skipping...
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | iqaluit
# Processing Record 5 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 2 | atuona
# Processing Record 7 of Set 2 | kitgum
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | biak
# Processing Record 10 of Set 2 | nanortalik
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | svetlyy
# Processing Record 13 of Set 2 | kulhudhuffushi
# Processing Record 14 of Set 2 | gannan
# Processing Record 15 of Set 2 | ahipara
# Processing Record 16 of Set 2 | bahia honda
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | ranikhet
# Processing Record 19 of Set 2 | wawa
# Processing Record 20 of Set 2 | himora
# City not found. Skipping...
# Processing Record 21 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 2 | thompson
# Processing Record 23 of Set 2 | guisa
# Processing Record 24 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 2 | geraldton
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | lahaina
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | pafos
# Processing Record 31 of Set 2 | agua verde
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | ulladulla
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | komsomolskiy
# Processing Record 37 of Set 2 | manaure
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | flin flon
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | chapais
# Processing Record 45 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | dudinka
# Processing Record 48 of Set 2 | klaksvik
# Processing Record 49 of Set 2 | boffa
# Processing Record 50 of Set 2 | lagoa
# Processing Record 1 of Set 3 | montepuez
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | bembereke
# Processing Record 4 of Set 3 | alofi
# Processing Record 5 of Set 3 | yueyang
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | atbasar
# Processing Record 8 of Set 3 | tawau
# Processing Record 9 of Set 3 | kui buri
# Processing Record 10 of Set 3 | egvekinot
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | pisco
# Processing Record 13 of Set 3 | bambous virieux
# Processing Record 14 of Set 3 | redding
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 3 | mount gambier
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | hirara
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | dubbo
# Processing Record 22 of Set 3 | coahuayana
# Processing Record 23 of Set 3 | mareeba
# Processing Record 24 of Set 3 | strezhevoy
# Processing Record 25 of Set 3 | burica
# City not found. Skipping...
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | padang
# Processing Record 28 of Set 3 | namatanai
# Processing Record 29 of Set 3 | tual
# Processing Record 30 of Set 3 | mackay
# Processing Record 31 of Set 3 | taywarah
# Processing Record 32 of Set 3 | vaitape
# Processing Record 33 of Set 3 | khatassy
# Processing Record 34 of Set 3 | hokitika
# Processing Record 35 of Set 3 | college
# Processing Record 36 of Set 3 | shelburne
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | el vigia
# Processing Record 39 of Set 3 | kahului
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | mankovo-kalitvenskoye
# City not found. Skipping...
# Processing Record 42 of Set 3 | batemans bay
# Processing Record 43 of Set 3 | panama city
# Processing Record 44 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 45 of Set 3 | kununurra
# Processing Record 46 of Set 3 | saint-georges
# Processing Record 47 of Set 3 | fortuna
# Processing Record 48 of Set 3 | viedma
# Processing Record 49 of Set 3 | camacha
# Processing Record 50 of Set 3 | mirabad
# Processing Record 1 of Set 4 | moose factory
# Processing Record 2 of Set 4 | bathsheba
# Processing Record 3 of Set 4 | pontes e lacerda
# Processing Record 4 of Set 4 | smyrna
# Processing Record 5 of Set 4 | noumea
# Processing Record 6 of Set 4 | esperance
# Processing Record 7 of Set 4 | atar
# Processing Record 8 of Set 4 | pedasi
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | salalah
# Processing Record 11 of Set 4 | thinadhoo
# Processing Record 12 of Set 4 | gushi
# Processing Record 13 of Set 4 | qaqortoq
# Processing Record 14 of Set 4 | dallas
# Processing Record 15 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 4 | fuxin
# Processing Record 17 of Set 4 | yeniseysk
# Processing Record 18 of Set 4 | zyryanka
# Processing Record 19 of Set 4 | acarau
# Processing Record 20 of Set 4 | leningradskiy
# Processing Record 21 of Set 4 | khvastovichi
# Processing Record 22 of Set 4 | hami
# Processing Record 23 of Set 4 | kaitangata
# Processing Record 24 of Set 4 | cerro largo
# Processing Record 25 of Set 4 | birjand
# Processing Record 26 of Set 4 | peniche
# Processing Record 27 of Set 4 | faanui
# Processing Record 28 of Set 4 | santiago
# Processing Record 29 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | mercedes
# Processing Record 33 of Set 4 | chara
# Processing Record 34 of Set 4 | ugoofaaru
# Processing Record 35 of Set 4 | bangassou
# Processing Record 36 of Set 4 | hofn
# Processing Record 37 of Set 4 | leh
# Processing Record 38 of Set 4 | bajil
# Processing Record 39 of Set 4 | najran
# Processing Record 40 of Set 4 | nalut
# Processing Record 41 of Set 4 | san andres
# Processing Record 42 of Set 4 | ostrovnoy
# Processing Record 43 of Set 4 | tabou
# Processing Record 44 of Set 4 | tebingtinggi
# Processing Record 45 of Set 4 | saint-philippe
# Processing Record 46 of Set 4 | butaritari
# Processing Record 47 of Set 4 | yerbogachen
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | sechura
# Processing Record 50 of Set 4 | sur
# Processing Record 1 of Set 5 | benguela
# Processing Record 2 of Set 5 | mar del plata
# Processing Record 3 of Set 5 | rosetta
# Processing Record 4 of Set 5 | port hedland
# Processing Record 5 of Set 5 | pevek
# Processing Record 6 of Set 5 | kirakira
# Processing Record 7 of Set 5 | mahenge
# Processing Record 8 of Set 5 | nantucket
# Processing Record 9 of Set 5 | wajir
# Processing Record 10 of Set 5 | pedro juan caballero
# Processing Record 11 of Set 5 | isangel
# Processing Record 12 of Set 5 | miraflores
# Processing Record 13 of Set 5 | svetlogorsk
# Processing Record 14 of Set 5 | balkhash
# Processing Record 15 of Set 5 | namanga
# Processing Record 16 of Set 5 | do rud
# City not found. Skipping...
# Processing Record 17 of Set 5 | olinda
# Processing Record 18 of Set 5 | ust-ishim
# Processing Record 19 of Set 5 | touros
# Processing Record 20 of Set 5 | zaqatala
# Processing Record 21 of Set 5 | victoria
# Processing Record 22 of Set 5 | san bartolome
# Processing Record 23 of Set 5 | kendari
# Processing Record 24 of Set 5 | vardo
# Processing Record 25 of Set 5 | chokurdakh
# Processing Record 26 of Set 5 | hay river
# Processing Record 27 of Set 5 | bethel
# Processing Record 28 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 5 | seoul
# Processing Record 30 of Set 5 | tucuman
# Processing Record 31 of Set 5 | caravelas
# Processing Record 32 of Set 5 | coquimbo
# Processing Record 33 of Set 5 | tarakan
# Processing Record 34 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 35 of Set 5 | innisfail
# Processing Record 36 of Set 5 | gaoual
# Processing Record 37 of Set 5 | sao filipe
# Processing Record 38 of Set 5 | chifeng
# Processing Record 39 of Set 5 | ikornnes
# Processing Record 40 of Set 5 | souillac
# Processing Record 41 of Set 5 | constitucion
# Processing Record 42 of Set 5 | sorong
# Processing Record 43 of Set 5 | ambon
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | lavumisa
# Processing Record 46 of Set 5 | kayiry
# Processing Record 47 of Set 5 | buzmeyin
# Processing Record 48 of Set 5 | jiayuguan
# Processing Record 49 of Set 5 | ahmadpur east
# Processing Record 50 of Set 5 | lasa
# Processing Record 1 of Set 6 | impfondo
# Processing Record 2 of Set 6 | sao felix do xingu
# Processing Record 3 of Set 6 | pangnirtung
# Processing Record 4 of Set 6 | puerto leguizamo
# Processing Record 5 of Set 6 | coihaique
# Processing Record 6 of Set 6 | severo-kurilsk
# Processing Record 7 of Set 6 | mandalgovi
# Processing Record 8 of Set 6 | agadez
# Processing Record 9 of Set 6 | airai
# Processing Record 10 of Set 6 | fort myers beach
# Processing Record 11 of Set 6 | sitka
# Processing Record 12 of Set 6 | bani
# Processing Record 13 of Set 6 | vore
# Processing Record 14 of Set 6 | faya
# Processing Record 15 of Set 6 | san antonio
# Processing Record 16 of Set 6 | ilave
# Processing Record 17 of Set 6 | iranshahr
# Processing Record 18 of Set 6 | carnarvon
# Processing Record 19 of Set 6 | skjervoy
# Processing Record 20 of Set 6 | okha
# Processing Record 21 of Set 6 | abu dhabi
# Processing Record 22 of Set 6 | cap malheureux
# Processing Record 23 of Set 6 | sibu
# Processing Record 24 of Set 6 | ialibu
# Processing Record 25 of Set 6 | baijiantan
# Processing Record 26 of Set 6 | bizhbulyak
# Processing Record 27 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 28 of Set 6 | new norfolk
# Processing Record 29 of Set 6 | xinmin
# Processing Record 30 of Set 6 | cururupu
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | byron bay
# Processing Record 34 of Set 6 | taloqan
# Processing Record 35 of Set 6 | dhidhdhoo
# Processing Record 36 of Set 6 | luderitz
# Processing Record 37 of Set 6 | brejo da madre de deus
# Processing Record 38 of Set 6 | potsdam
# Processing Record 39 of Set 6 | nakhon phanom
# Processing Record 40 of Set 6 | bulgan
# Processing Record 41 of Set 6 | darnah
# Processing Record 42 of Set 6 | murray bridge
# Processing Record 43 of Set 6 | guican
# Processing Record 44 of Set 6 | okhotsk
# Processing Record 45 of Set 6 | panuco
# Processing Record 46 of Set 6 | chengmai
# City not found. Skipping...
# Processing Record 47 of Set 6 | opuwo
# Processing Record 48 of Set 6 | arthur
# Processing Record 49 of Set 6 | vanimo
# Processing Record 50 of Set 6 | sibolga
# Processing Record 1 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 7 | jining
# Processing Record 3 of Set 7 | dalnegorsk
# Processing Record 4 of Set 7 | the valley
# Processing Record 5 of Set 7 | luoyang
# Processing Record 6 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 7 | mirganj
# Processing Record 8 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 7 | lewisburg
# Processing Record 10 of Set 7 | havoysund
# Processing Record 11 of Set 7 | bonavista
# Processing Record 12 of Set 7 | shingu
# Processing Record 13 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 7 | bilma
# Processing Record 15 of Set 7 | ponta do sol
# Processing Record 16 of Set 7 | huarmey
# Processing Record 17 of Set 7 | gladstone
# Processing Record 18 of Set 7 | yichang
# Processing Record 19 of Set 7 | morehead
# Processing Record 20 of Set 7 | zwettl
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 7 | krasnaya gora
# Processing Record 24 of Set 7 | san cristobal
# Processing Record 25 of Set 7 | terney
# Processing Record 26 of Set 7 | kisanga
# Processing Record 27 of Set 7 | celina
# Processing Record 28 of Set 7 | hunterville
# Processing Record 29 of Set 7 | augustow
# Processing Record 30 of Set 7 | hasaki
# Processing Record 31 of Set 7 | aksu
# Processing Record 32 of Set 7 | mindelo
# Processing Record 33 of Set 7 | savannakhet
# Processing Record 34 of Set 7 | shimoda
# Processing Record 35 of Set 7 | severo-yeniseyskiy
# Processing Record 36 of Set 7 | les cayes
# Processing Record 37 of Set 7 | srivardhan
# Processing Record 38 of Set 7 | virginia beach
# Processing Record 39 of Set 7 | cidreira
# Processing Record 40 of Set 7 | kyzyl-suu
# Processing Record 41 of Set 7 | te anau
# Processing Record 42 of Set 7 | grindavik
# Processing Record 43 of Set 7 | georgetown
# Processing Record 44 of Set 7 | mubende
# Processing Record 45 of Set 7 | nsoko
# Processing Record 46 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 7 | mahebourg
# Processing Record 48 of Set 7 | bua yai
# Processing Record 49 of Set 7 | berdigestyakh
# Processing Record 50 of Set 7 | russkiy aktash
# Processing Record 1 of Set 8 | nador
# Processing Record 2 of Set 8 | pochutla
# Processing Record 3 of Set 8 | colares
# Processing Record 4 of Set 8 | san quintin
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | jerantut
# Processing Record 7 of Set 8 | broome
# Processing Record 8 of Set 8 | boa vista
# Processing Record 9 of Set 8 | shebalino
# Processing Record 10 of Set 8 | olavarria
# Processing Record 11 of Set 8 | husavik
# Processing Record 12 of Set 8 | darhan
# Processing Record 13 of Set 8 | hatillo
# Processing Record 14 of Set 8 | jashpurnagar
# Processing Record 15 of Set 8 | singureni
# Processing Record 16 of Set 8 | guerrero negro
# Processing Record 17 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 8 | wum
# Processing Record 19 of Set 8 | cayenne
# Processing Record 20 of Set 8 | kenai
# Processing Record 21 of Set 8 | along
# Processing Record 22 of Set 8 | taoudenni
# Processing Record 23 of Set 8 | codrington
# Processing Record 24 of Set 8 | farafangana
# Processing Record 25 of Set 8 | khatanga
# Processing Record 26 of Set 8 | hirado
# Processing Record 27 of Set 8 | la ronge
# Processing Record 28 of Set 8 | wonthaggi
# Processing Record 29 of Set 8 | henties bay
# Processing Record 30 of Set 8 | lamu
# Processing Record 31 of Set 8 | dunedin
# Processing Record 32 of Set 8 | yakeshi
# Processing Record 33 of Set 8 | qurunbaliyah
# City not found. Skipping...
# Processing Record 34 of Set 8 | kurchum
# Processing Record 35 of Set 8 | ixtapa
# Processing Record 36 of Set 8 | hamilton
# Processing Record 37 of Set 8 | gorontalo
# Processing Record 38 of Set 8 | mahajanga
# Processing Record 39 of Set 8 | unity
# Processing Record 40 of Set 8 | san lazaro
# Processing Record 41 of Set 8 | glendive
# Processing Record 42 of Set 8 | vila
# Processing Record 43 of Set 8 | fort nelson
# Processing Record 44 of Set 8 | kaniama
# Processing Record 45 of Set 8 | fare
# Processing Record 46 of Set 8 | wanlaweyn
# Processing Record 47 of Set 8 | gorahun
# Processing Record 48 of Set 8 | grand gaube
# Processing Record 49 of Set 8 | wanning
# Processing Record 50 of Set 8 | jacqueville
# Processing Record 1 of Set 9 | deming
# Processing Record 2 of Set 9 | oranjestad
# Processing Record 3 of Set 9 | tsotilion
# Processing Record 4 of Set 9 | fairbanks
# Processing Record 5 of Set 9 | presidencia roque saenz pena
# Processing Record 6 of Set 9 | ende
# Processing Record 7 of Set 9 | leshukonskoye
# Processing Record 8 of Set 9 | bozoum
# Processing Record 9 of Set 9 | brae
# Processing Record 10 of Set 9 | bosaso
# Processing Record 11 of Set 9 | aktau
# Processing Record 12 of Set 9 | ikom
# Processing Record 13 of Set 9 | port macquarie
# Processing Record 14 of Set 9 | jubayl
# City not found. Skipping...
# Processing Record 15 of Set 9 | rio gallegos
# Processing Record 16 of Set 9 | bengkulu
# Processing Record 17 of Set 9 | umm lajj
# Processing Record 18 of Set 9 | havre-saint-pierre
# Processing Record 19 of Set 9 | san patricio
# Processing Record 20 of Set 9 | yarmouth
# Processing Record 21 of Set 9 | vao
# Processing Record 22 of Set 9 | olafsvik
# Processing Record 23 of Set 9 | san policarpo
# Processing Record 24 of Set 9 | vakhrushev
# Processing Record 25 of Set 9 | daru
# Processing Record 26 of Set 9 | sapiranga
# Processing Record 27 of Set 9 | ponta delgada
# Processing Record 28 of Set 9 | illapel
# Processing Record 29 of Set 9 | chernyshevskiy
# Processing Record 30 of Set 9 | kargasok
# Processing Record 31 of Set 9 | severnyy
# Processing Record 32 of Set 9 | simbahan
# Processing Record 33 of Set 9 | lerwick
# Processing Record 34 of Set 9 | batticaloa
# Processing Record 35 of Set 9 | lieto
# Processing Record 36 of Set 9 | mersing
# Processing Record 37 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 38 of Set 9 | haines junction
# Processing Record 39 of Set 9 | qasigiannguit
# Processing Record 40 of Set 9 | port hardy
# Processing Record 41 of Set 9 | kishtwar
# Processing Record 42 of Set 9 | sikonge
# Processing Record 43 of Set 9 | comodoro rivadavia
# Processing Record 44 of Set 9 | zwedru
# Processing Record 45 of Set 9 | illela
# Processing Record 46 of Set 9 | catamarca
# Processing Record 47 of Set 9 | vanavara
# Processing Record 48 of Set 9 | olenegorsk
# Processing Record 49 of Set 9 | la baule-escoublac
# Processing Record 50 of Set 9 | kibala
# Processing Record 1 of Set 10 | lufilufi
# Processing Record 2 of Set 10 | nsanje
# Processing Record 3 of Set 10 | turukhansk
# Processing Record 4 of Set 10 | tsaratanana
# Processing Record 5 of Set 10 | betare oya
# Processing Record 6 of Set 10 | nemuro
# Processing Record 7 of Set 10 | maniitsoq
# Processing Record 8 of Set 10 | marawi
# Processing Record 9 of Set 10 | la asuncion
# Processing Record 10 of Set 10 | riyaq
# City not found. Skipping...
# Processing Record 11 of Set 10 | katherine
# Processing Record 12 of Set 10 | olivet
# Processing Record 13 of Set 10 | ciro marina
# Processing Record 14 of Set 10 | cabra
# Processing Record 15 of Set 10 | arvi
# Processing Record 16 of Set 10 | puerto escondido
# Processing Record 17 of Set 10 | tanete
# Processing Record 18 of Set 10 | portland
# Processing Record 19 of Set 10 | simpang
# Processing Record 20 of Set 10 | vammala
# Processing Record 21 of Set 10 | chernyatyn
# Processing Record 22 of Set 10 | agva
# City not found. Skipping...
# Processing Record 23 of Set 10 | katsuura
# Processing Record 24 of Set 10 | nhamunda
# Processing Record 25 of Set 10 | saint-pierre
# Processing Record 26 of Set 10 | manadhoo
# Processing Record 27 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 10 | norrkoping
# Processing Record 29 of Set 10 | port augusta
# Processing Record 30 of Set 10 | troitsk
# Processing Record 31 of Set 10 | hwange
# Processing Record 32 of Set 10 | villablino
# Processing Record 33 of Set 10 | meadow lake
# Processing Record 34 of Set 10 | rocha
# Processing Record 35 of Set 10 | oranjemund
# Processing Record 36 of Set 10 | lesozavodsk
# Processing Record 37 of Set 10 | mount darwin
# Processing Record 38 of Set 10 | champerico
# Processing Record 39 of Set 10 | lompoc
# Processing Record 40 of Set 10 | hun
# Processing Record 41 of Set 10 | mahibadhoo
# Processing Record 42 of Set 10 | sinnamary
# Processing Record 43 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 10 | bandarbeyla
# Processing Record 45 of Set 10 | andrews
# Processing Record 46 of Set 10 | saldanha
# Processing Record 47 of Set 10 | berberati
# Processing Record 48 of Set 10 | pastavy
# Processing Record 49 of Set 10 | afmadu
# City not found. Skipping...
# Processing Record 50 of Set 10 | levokumskoye
# Processing Record 1 of Set 11 | timaru
# Processing Record 2 of Set 11 | kavieng
# Processing Record 3 of Set 11 | wamba
# Processing Record 4 of Set 11 | bonthe
# Processing Record 5 of Set 11 | doha
# Processing Record 6 of Set 11 | kamskiye polyany
# Processing Record 7 of Set 11 | gazanjyk
# Processing Record 8 of Set 11 | carrickmacross
# Processing Record 9 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 10 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 11 | koryazhma
# Processing Record 12 of Set 11 | semirom
# Processing Record 13 of Set 11 | lubumbashi
# Processing Record 14 of Set 11 | candolim
# Processing Record 15 of Set 11 | limon
# Processing Record 16 of Set 11 | paita
# Processing Record 17 of Set 11 | sabang
# Processing Record 18 of Set 11 | tadine
# Processing Record 19 of Set 11 | rehlingen-siersburg
# Processing Record 20 of Set 11 | nea kallikratia
# Processing Record 21 of Set 11 | oktyabrskoye
# Processing Record 22 of Set 11 | ponazyrevo
# Processing Record 23 of Set 11 | palmer
# Processing Record 24 of Set 11 | port-gentil
# Processing Record 25 of Set 11 | atambua
# Processing Record 26 of Set 11 | vizinga
# Processing Record 27 of Set 11 | dondo
# Processing Record 28 of Set 11 | plered
# City not found. Skipping...
# Processing Record 29 of Set 11 | paytug
# City not found. Skipping...
# Processing Record 30 of Set 11 | marsa matruh
# Processing Record 31 of Set 11 | ostersund
# Processing Record 32 of Set 11 | valparaiso
# Processing Record 33 of Set 11 | west bay
# Processing Record 34 of Set 11 | mogadishu
# Processing Record 35 of Set 11 | dandong
# Processing Record 36 of Set 11 | urumqi
# Processing Record 37 of Set 11 | lorengau
# Processing Record 38 of Set 11 | walvis bay
# Processing Record 39 of Set 11 | sarangani
# Processing Record 40 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 11 | chlorakas
# Processing Record 42 of Set 11 | buala
# Processing Record 43 of Set 11 | beloha
# Processing Record 44 of Set 11 | kondinskoye
# Processing Record 45 of Set 11 | alanya
# Processing Record 46 of Set 11 | bourail
# Processing Record 47 of Set 11 | roald
# Processing Record 48 of Set 11 | zhigansk
# Processing Record 49 of Set 11 | frutal
# Processing Record 50 of Set 11 | maloy
# Processing Record 1 of Set 12 | mantiquil
# Processing Record 2 of Set 12 | taltal
# Processing Record 3 of Set 12 | muros
# Processing Record 4 of Set 12 | inuvik
# Processing Record 5 of Set 12 | fort abbas
# Processing Record 6 of Set 12 | jalu
# Processing Record 7 of Set 12 | kudahuvadhoo
# Processing Record 8 of Set 12 | vila franca do campo
# Processing Record 9 of Set 12 | sa kaeo
# Processing Record 10 of Set 12 | makakilo city
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | menongue
# Processing Record 13 of Set 12 | anqing
# Processing Record 14 of Set 12 | mamallapuram
# Processing Record 15 of Set 12 | ndjole
# Processing Record 16 of Set 12 | matay
# Processing Record 17 of Set 12 | lossiemouth
# Processing Record 18 of Set 12 | half moon bay
# Processing Record 19 of Set 12 | christchurch
# Processing Record 20 of Set 12 | dong hoi
# Processing Record 21 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 12 | belousovka
# Processing Record 23 of Set 12 | mayumba
# Processing Record 24 of Set 12 | bama
# Processing Record 25 of Set 12 | cam ranh
# Processing Record 26 of Set 12 | takoradi
# Processing Record 27 of Set 12 | nepalganj
# City not found. Skipping...
# Processing Record 28 of Set 12 | tecpan
# Processing Record 29 of Set 12 | baiyin
# Processing Record 30 of Set 12 | kysyl-syr
# Processing Record 31 of Set 12 | gusau
# Processing Record 32 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 12 | kantunilkin
# Processing Record 35 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 12 | ca mau
# Processing Record 37 of Set 12 | poya
# Processing Record 38 of Set 12 | vestmannaeyjar
# Processing Record 39 of Set 12 | tomatlan
# Processing Record 40 of Set 12 | mayo
# Processing Record 41 of Set 12 | silver city
# Processing Record 42 of Set 12 | lalibela
# Processing Record 43 of Set 12 | shenjiamen
# Processing Record 44 of Set 12 | talakan
# Processing Record 45 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 46 of Set 12 | manggar
# Processing Record 47 of Set 12 | barra patuca
# Processing Record 48 of Set 12 | kaeo
# Processing Record 49 of Set 12 | coolum beach
# Processing Record 50 of Set 12 | zheleznodorozhnyy
# Processing Record 1 of Set 13 | bage
# Processing Record 2 of Set 13 | cabedelo
# Processing Record 3 of Set 13 | knysna
# Processing Record 4 of Set 13 | narsaq
# Processing Record 5 of Set 13 | rio brilhante
# Processing Record 6 of Set 13 | avera
# Processing Record 7 of Set 13 | forbes
# Processing Record 8 of Set 13 | praya
# Processing Record 9 of Set 13 | pacifica
# Processing Record 10 of Set 13 | saint anthony
# Processing Record 11 of Set 13 | teya
# Processing Record 12 of Set 13 | lages
# Processing Record 13 of Set 13 | manokwari
# Processing Record 14 of Set 13 | suihua
# Processing Record 15 of Set 13 | abu kamal
# Processing Record 16 of Set 13 | columbus
# Processing Record 17 of Set 13 | fort-shevchenko
# Processing Record 18 of Set 13 | umbertide
# Processing Record 19 of Set 13 | lexington park
# Processing Record 20 of Set 13 | banyo
# Processing Record 21 of Set 13 | wahpeton
# Processing Record 22 of Set 13 | meulaboh
# Processing Record 23 of Set 13 | mehamn
# Processing Record 24 of Set 13 | skibbereen
# Processing Record 25 of Set 13 | tongzi
# Processing Record 26 of Set 13 | neos pirgos
# City not found. Skipping...
# Processing Record 27 of Set 13 | alice springs
# Processing Record 28 of Set 13 | limbang
# Processing Record 29 of Set 13 | san jose
# Processing Record 30 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 13 | qadirpur ran
# Processing Record 32 of Set 13 | bilibino
# Processing Record 33 of Set 13 | palauig
# Processing Record 34 of Set 13 | quatre cocos
# Processing Record 35 of Set 13 | ler
# Processing Record 36 of Set 13 | bumba
# Processing Record 37 of Set 13 | jakar
# Processing Record 38 of Set 13 | karlskrona
# Processing Record 39 of Set 13 | asekeyevo
# Processing Record 40 of Set 13 | miri
# Processing Record 41 of Set 13 | sorland
# Processing Record 42 of Set 13 | road town
# Processing Record 43 of Set 13 | kincardine
# Processing Record 44 of Set 13 | forestville
# Processing Record 45 of Set 13 | nuuk
# Processing Record 46 of Set 13 | oeiras do para
# Processing Record 47 of Set 13 | payo
# Processing Record 48 of Set 13 | yerofey pavlovich
# Processing Record 49 of Set 13 | gamba
# Processing Record 50 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 1 of Set 14 | ancud
# Processing Record 2 of Set 14 | longhua
# Processing Record 3 of Set 14 | ransang
# Processing Record 4 of Set 14 | hailey
# Processing Record 5 of Set 14 | oyon
# Processing Record 6 of Set 14 | port lincoln
# Processing Record 7 of Set 14 | belyy yar
# Processing Record 8 of Set 14 | great falls
# Processing Record 9 of Set 14 | pechenga
# Processing Record 10 of Set 14 | porto walter
# Processing Record 11 of Set 14 | plettenberg bay
# Processing Record 12 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 14 | urengoy
# Processing Record 14 of Set 14 | jatai
# Processing Record 15 of Set 14 | sault sainte marie
# Processing Record 16 of Set 14 | baran
# Processing Record 17 of Set 14 | kosa
# Processing Record 18 of Set 14 | back mountain
# Processing Record 19 of Set 14 | inhambane
# Processing Record 20 of Set 14 | kihei
# Processing Record 21 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 22 of Set 14 | gubkinskiy
# Processing Record 23 of Set 14 | yulara
# Processing Record 24 of Set 14 | malkangiri
# Processing Record 25 of Set 14 | portobelo
# Processing Record 26 of Set 14 | arona
# Processing Record 27 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 14 | sao joao da barra
# Processing Record 29 of Set 14 | dicabisagan
# Processing Record 30 of Set 14 | ilhabela
# Processing Record 31 of Set 14 | khawhai
# Processing Record 32 of Set 14 | bichura
# Processing Record 33 of Set 14 | keshan
# City not found. Skipping...
# Processing Record 34 of Set 14 | akdepe
# Processing Record 35 of Set 14 | alexandria
# Processing Record 36 of Set 14 | puerto colombia
# Processing Record 37 of Set 14 | north myrtle beach
# Processing Record 38 of Set 14 | merauke
# Processing Record 39 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 14 | leiyang
# Processing Record 41 of Set 14 | amahai
# Processing Record 42 of Set 14 | sucua
# Processing Record 43 of Set 14 | brest
# Processing Record 44 of Set 14 | mokhsogollokh
# Processing Record 45 of Set 14 | gat
# Processing Record 46 of Set 14 | chicama
# Processing Record 47 of Set 14 | manta
# Processing Record 48 of Set 14 | dafeng
# Processing Record 49 of Set 14 | xinqing
# Processing Record 50 of Set 14 | manakara
# Processing Record 1 of Set 15 | bukama
# Processing Record 2 of Set 15 | ampanihy
# Processing Record 3 of Set 15 | shellbrook
# Processing Record 4 of Set 15 | ariogala
# Processing Record 5 of Set 15 | naryan-mar
# Processing Record 6 of Set 15 | amazar
# Processing Record 7 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 15 | pangai
# Processing Record 9 of Set 15 | neiafu
# Processing Record 10 of Set 15 | sept-iles
# Processing Record 11 of Set 15 | marfino
# Processing Record 12 of Set 15 | kamaishi
# Processing Record 13 of Set 15 | vuktyl
# Processing Record 14 of Set 15 | sandpoint
# Processing Record 15 of Set 15 | kovur
# Processing Record 16 of Set 15 | guarapari
# Processing Record 17 of Set 15 | kresttsy
# Processing Record 18 of Set 15 | shache
# Processing Record 19 of Set 15 | svetlaya
# Processing Record 20 of Set 15 | labuhan
# Processing Record 21 of Set 15 | hoquiam
# Processing Record 22 of Set 15 | vila velha
# Processing Record 23 of Set 15 | honningsvag
# Processing Record 24 of Set 15 | paamiut
# Processing Record 25 of Set 15 | baiquan
# Processing Record 26 of Set 15 | pittsburg
# Processing Record 27 of Set 15 | bubaque
# Processing Record 28 of Set 15 | balkanabat
# Processing Record 29 of Set 15 | borovoy
# Processing Record 30 of Set 15 | loubomo
# Processing Record 31 of Set 15 | adamovka
# Processing Record 32 of Set 15 | grootfontein
# Processing Record 33 of Set 15 | sami
# Processing Record 34 of Set 15 | ahuimanu
# Processing Record 35 of Set 15 | high level
# Processing Record 36 of Set 15 | palembang
# Processing Record 37 of Set 15 | chegdomyn
# Processing Record 38 of Set 15 | waipawa
# Processing Record 39 of Set 15 | batagay-alyta
# Processing Record 40 of Set 15 | awbari
# Processing Record 41 of Set 15 | abu samrah
# Processing Record 42 of Set 15 | cintalapa
# Processing Record 43 of Set 15 | obo
# Processing Record 44 of Set 15 | songkhla
# Processing Record 45 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 15 | vicuna
# Processing Record 47 of Set 15 | quelimane
# Processing Record 48 of Set 15 | anchorage
# Processing Record 49 of Set 15 | karratha
# Processing Record 50 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 1 of Set 16 | sembakung
# Processing Record 2 of Set 16 | muskogee
# Processing Record 3 of Set 16 | tastur
# Processing Record 4 of Set 16 | denpasar
# Processing Record 5 of Set 16 | apomu
# Processing Record 6 of Set 16 | ndele
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany      US  42.6001  -73.9662     74.73        87          99
# 1    Tuktoyaktuk      CA  69.4541 -133.0374     48.20        81          75
# 2         Usinsk      RU  65.9939   57.5281     49.75        77         100
# 3           Naze      JP  28.3667  129.4833     86.92        75          16
# 4         Dikson      RU  73.5069   80.5464     46.90        97         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 688     Muskogee      US  35.5834  -95.3336     97.95        34           0
# 689       Tastur      TN  36.5513    9.4431     77.02        46           0
# 690     Denpasar      ID  -8.6500  115.2167     78.46        65          40
# 691        Apomu      NG   7.3333    4.1833     71.19        97         100
# 692        Ndele      CF   8.4109   20.6473     69.30        94          99
#
#      Wind Speed Current Description
# 0          6.51     overcast clouds
# 1          9.22       broken clouds
# 2         10.76     overcast clouds
# 3          0.60          few clouds
# 4         11.54          light rain
# ..          ...                 ...
# 688        6.91           clear sky
# 689        2.21           clear sky
# 690        3.44    scattered clouds
# 691        2.75          light rain
# 692        2.95     overcast clouds
#
# [693 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
